# %%
import re
import os
import pandas as pd
import glob
import pandas
import mmap
import ntpath

# %%
# !ls
# Out:
# bell-ring-01.mp3              jupyter
# error-alert.mp3               jupyter_source_explorer.ipynb
# event_triggers.csv            notebook
# event_triggers.pkl            reader_test_notebook.ipynb
# events.html                   transformer-1.mp3

# %%
#os.chdir("./jupyter")

# %%
files_to_be_searched = []

for path, subdirs, files in os.walk(r'/Users/james/Documents/code/thesis-notebooks/notebook/'):
    for filename in files:
        if filename.endswith('.js') or filename.endswith('.py'):
            files_to_be_searched.append(os.path.join(path, filename))

# %%
len(files_to_be_searched)
# Out:
# 201

# %%
# Note: search_term needs to be in byte format, easiest (only?) way to do this is to prefix the string with a 'b'
def search_files_for_term(search_term, files_to_be_searched):
    narrowed_files = []
    # Narrow down files
    for file in files_to_be_searched:
        if os.stat(file).st_size != 0: # If file is not empty
            open_file = open(file,'r')
            # Create a memory map for easy searching
            mem_map = mmap.mmap(open_file.fileno(), 0, access=mmap.ACCESS_READ)
            if mem_map.find(search_term) != -1:
                 narrowed_files.append(file)
                    
    # Search files for lines containing search term    
    search_results = []
    for file in narrowed_files:
        #head, tail = ntpath.split(file)
        file_path = file.split('thesis-notebooks/notebook/')[1]
        search_term_as_string = search_term.decode('utf-8')
        line_tuples = get_line_number_and_string(search_term_as_string, file)

        for line in line_tuples:
            search_results.append([file_path,line[0],line[1]])
            
    return search_results

# %%
def get_line_number_and_string(search_term, filename):
    line_numbers = []
    with open(filename) as f:
        for i, line_text in enumerate(f):
            line_number = i+1
            if str(search_term) in line_text:
                line_numbers.append((line_number,line_text))
    return line_numbers

# %%
search_term = b'events.trigger'

results = search_files_for_term(search_term, files_to_be_searched)

# %%
results
# Out:
# [['notebook/static/base/js/keyboard.js',
#   378,
#   "            this.events.trigger('rebuild.QuickHelp');\n"],
#  ['notebook/static/base/js/keyboard.js',
#   392,
#   "        this.events.trigger('rebuild.QuickHelp');\n"],
#  ['notebook/static/base/js/keyboard.js',
#   413,
#   "            this.events.trigger('rebuild.QuickHelp');\n"],
#  ['notebook/static/edit/js/editor.js',
#   55,
#   "            that.events.trigger('config_changed.Editor', {config: that.config});\n"],
#  ['notebook/static/edit/js/editor.js',
#   88,
#   '                that.events.trigger("file_loaded.Editor", model);\n'],
#  ['notebook/static/edit/js/editor.js',
#   92,
#   '                that.events.trigger("file_load_failed.Editor", error);\n'],
#  ['notebook/static/edit/js/editor.js',
#   133,
#   '            that.events.trigger("mode_changed.Editor", modeinfo);\n'],
#  ['notebook/static/edit/js/editor.js',
#   149,
#   "                that.events.trigger('file_renamed.Editor', model);\n"],
#  ['notebook/static/edit/js/editor.js',
#   171,
#   '        that.events.trigger("file_saving.Editor");\n'],
#  ['notebook/static/edit/js/editor.js',
#   173,
#   '            that.events.trigger("file_saved.Editor", data);\n'],
#  ['notebook/static/edit/js/editor.js',
#   186,
#   '            this.events.trigger("save_status_clean.Editor");\n'],
#  ['notebook/static/edit/js/editor.js',
#   189,
#   '            this.events.trigger("save_status_dirty.Editor");\n'],
#  ['notebook/static/edit/js/editor.js',
#   215,
#   "            that.events.trigger('config_changed.Editor', {config: that.config})\n"],
#  ['notebook/static/notebook/js/actions.js',
#   436,
#   "                events.trigger('resize-header.Page');\n"],
#  ['notebook/static/notebook/js/actions.js',
#   444,
#   "                events.trigger('resize-header.Page');\n"],
#  ['notebook/static/notebook/js/cell.js',
#   171,
#   "            this.events.trigger('select.Cell', {'cell':this, 'extendSelection':event.shiftKey});\n"],
#  ['notebook/static/notebook/js/cell.js',
#   174,
#   "            this.events.trigger('select.Cell', {'cell': this});\n"],
#  ['notebook/static/notebook/js/cell.js',
#   192,
#   '                that.events.trigger("set_dirty.Notebook", {value: true});\n'],
#  ['notebook/static/notebook/js/cell.js',
#   198,
#   "                    that.events.trigger('select.Cell', {'cell':that});\n"],
#  ['notebook/static/notebook/js/cell.js',
#   200,
#   "                that.events.trigger('edit_mode.Cell', {cell: that});\n"],
#  ['notebook/static/notebook/js/cell.js',
#   205,
#   "                that.events.trigger('command_mode.Cell', {cell: that});\n"],
#  ['notebook/static/notebook/js/cell.js',
#   211,
#   "                this.events.trigger('select.Cell', {'cell':that});\n"],
#  ['notebook/static/notebook/js/cell.js',
#   745,
#   "            cell.events.trigger('unrecognized_cell.Cell', {cell: cell});\n"],
#  ['notebook/static/notebook/js/celltoolbar.js',
#   185,
#   "        events.trigger('preset_added.CellToolbar', {name: name});\n"],
#  ['notebook/static/notebook/js/celltoolbar.js',
#   203,
#   "            events.trigger('unregistered_preset.CellToolbar', {name: name});\n"],
#  ['notebook/static/notebook/js/celltoolbar.js',
#   247,
#   "        events.trigger('preset_activated.CellToolbar', {name: preset_name});\n"],
#  ['notebook/static/notebook/js/codecell.js',
#   336,
#   "        this.events.trigger('execute.CodeCell', {cell: this});\n"],
#  ['notebook/static/notebook/js/codecell.js',
#   366,
#   "        this.events.trigger('open_with_text.Pager', payload);\n"],
#  ['notebook/static/notebook/js/codecell.js',
#   376,
#   "        this.events.trigger('set_dirty.Notebook', {value: true});\n"],
#  ['notebook/static/notebook/js/codecell.js',
#   390,
#   "        this.events.trigger('set_next_input.Notebook', data);\n"],
#  ['notebook/static/notebook/js/kernelselector.js',
#   227,
#   '                this.events.trigger("spec_match_found.Kernel", {\n'],
#  ['notebook/static/notebook/js/kernelselector.js',
#   234,
#   '                this.events.trigger("spec_not_found.Kernel", {\n'],
#  ['notebook/static/notebook/js/kernelselector.js',
#   248,
#   "        this.events.trigger('spec_changed.Kernel', ks);\n"],
#  ['notebook/static/notebook/js/kernelselector.js',
#   282,
#   "                        that.events.trigger('no_kernel.Kernel');\n"],
#  ['notebook/static/notebook/js/main.js',
#   170,
#   "        events.trigger('app_initialized.NotebookApp');\n"],
#  ['notebook/static/notebook/js/menubar.js',
#   97,
#   "        this.events.trigger('resize-header.Page');\n"],
#  ['notebook/static/notebook/js/notebook.js',
#   394,
#   "        this.events.trigger('set_dirty.Notebook', {value: value});\n"],
#  ['notebook/static/notebook/js/notebook.js',
#   730,
#   "                this.events.trigger('selected_cell_type_changed.Notebook',\n"],
#  ['notebook/static/notebook/js/notebook.js',
#   734,
#   "                this.events.trigger('selected_cell_type_changed.Notebook',\n"],
#  ['notebook/static/notebook/js/notebook.js',
#   793,
#   "            this.events.trigger('command_mode.Notebook');\n"],
#  ['notebook/static/notebook/js/notebook.js',
#   820,
#   "            this.events.trigger('edit_mode.Notebook');\n"],
#  ['notebook/static/notebook/js/notebook.js',
#   1036,
#   "            this.events.trigger('delete.Cell', {'cell': cell, 'index': indices[i]});\n"],
#  ['notebook/static/notebook/js/notebook.js',
#   1177,
#   "                this.events.trigger('create.Cell', {'cell': cell, 'index': index});\n"],
#  ['notebook/static/notebook/js/notebook.js',
#   2328,
#   '            this.events.trigger("trust_changed.Notebook", trusted);\n'],
#  ['notebook/static/notebook/js/notebook.js',
#   2361,
#   '            this.events.trigger("trust_changed.Notebook", trusted);\n'],
#  ['notebook/static/notebook/js/notebook.js',
#   2389,
#   '            this.events.trigger("autosave_enabled.Notebook", interval);\n'],
#  ['notebook/static/notebook/js/notebook.js',
#   2392,
#   '            this.events.trigger("autosave_disabled.Notebook");\n'],
#  ['notebook/static/notebook/js/notebook.js',
#   2408,
#   "            this.events.trigger('notebook_save_failed.Notebook', error);\n"],
#  ['notebook/static/notebook/js/notebook.js',
#   2412,
#   "            this.events.trigger('notebook_save_failed.Notebook', error);\n"],
#  ['notebook/static/notebook/js/notebook.js',
#   2418,
#   "        this.events.trigger('before_save.Notebook');\n"],
#  ['notebook/static/notebook/js/notebook.js',
#   2433,
#   "                    that.events.trigger('notebook_save_failed.Notebook', error);\n"],
#  ['notebook/static/notebook/js/notebook.js',
#   2516,
#   "        this.events.trigger('notebook_saved.Notebook');\n"],
#  ['notebook/static/notebook/js/notebook.js',
#   2616,
#   "                    that.events.trigger('notebook_copy_failed', error);\n"],
#  ['notebook/static/notebook/js/notebook.js',
#   2653,
#   "                that.events.trigger('notebook_renamed.Notebook', json);\n"],
#  ['notebook/static/notebook/js/notebook.js',
#   2673,
#   "        this.events.trigger('notebook_loading.Notebook');\n"],
#  ['notebook/static/notebook/js/notebook.js',
#   2825,
#   "            this.events.trigger('notebook_read_only.Notebook');\n"],
#  ['notebook/static/notebook/js/notebook.js',
#   2830,
#   "        this.events.trigger('notebook_loaded.Notebook');\n"],
#  ['notebook/static/notebook/js/notebook.js',
#   2843,
#   "        this.events.trigger('notebook_load_failed.Notebook', error);\n"],
#  ['notebook/static/notebook/js/notebook.js',
#   2903,
#   "                that.events.trigger('list_checkpoints_failed.Notebook', error);\n"],
#  ['notebook/static/notebook/js/notebook.js',
#   2920,
#   "        this.events.trigger('checkpoints_listed.Notebook', [data]);\n"],
#  ['notebook/static/notebook/js/notebook.js',
#   2931,
#   "                that.events.trigger('checkpoint_failed.Notebook', error);\n"],
#  ['notebook/static/notebook/js/notebook.js',
#   2943,
#   "        this.events.trigger('checkpoint_created.Notebook', data);\n"],
#  ['notebook/static/notebook/js/notebook.js',
#   2999,
#   "        this.events.trigger('notebook_restoring.Notebook', checkpoint);\n"],
#  ['notebook/static/notebook/js/notebook.js',
#   3004,
#   "                that.events.trigger('checkpoint_restore_failed.Notebook', error);\n"],
#  ['notebook/static/notebook/js/notebook.js',
#   3013,
#   "        this.events.trigger('checkpoint_restored.Notebook');\n"],
#  ['notebook/static/notebook/js/notebook.js',
#   3023,
#   "        this.events.trigger('notebook_restoring.Notebook', checkpoint);\n"],
#  ['notebook/static/notebook/js/notebook.js',
#   3028,
#   "                that.events.trigger('checkpoint_delete_failed.Notebook', error);\n"],
#  ['notebook/static/notebook/js/notebook.js',
#   3037,
#   "        this.events.trigger('checkpoint_deleted.Notebook');\n"],
#  ['notebook/static/notebook/js/outputarea.js',
#   524,
#   "                    that.events.trigger('unrecognized_output.OutputArea', {output: json});\n"],
#  ['notebook/static/notebook/js/outputarea.js',
#   577,
#   "                this.events.trigger('output_appended.OutputArea', [type, value, md, toinsert]);\n"],
#  ['notebook/static/notebook/js/outputarea.js',
#   828,
#   "        this.events.trigger('send_input_reply.Kernel', value);\n"],
#  ['notebook/static/notebook/js/textcell.js',
#   297,
#   '                that.events.trigger("rendered.MarkdownCell", {cell: that});\n'],
#  ['notebook/static/notebook/js/tooltip.js',
#   125,
#   "        this.events.trigger('open_with_text.Pager', this._reply.content);\n"],
#  ['notebook/static/notebook/js/tour.js',
#   99,
#   "                onShow: function(tour) { events.trigger('kernel_idle.Kernel');},\n"],
#  ['notebook/static/notebook/js/tour.js',
#   105,
#   "                onShow: function(tour) { events.trigger('kernel_busy.Kernel'); },\n"],
#  ['notebook/static/notebook/js/tour.js',
#   111,
#   "                onHide: function(tour) { events.trigger('kernel_idle.Kernel'); },\n"],
#  ['notebook/static/services/kernels/kernel.js',
#   184,
#   "        this.events.trigger('kernel_starting.Kernel', {kernel: this});\n"],
#  ['notebook/static/services/kernels/kernel.js',
#   187,
#   "            that.events.trigger('kernel_created.Kernel', {kernel: that});\n"],
#  ['notebook/static/services/kernels/kernel.js',
#   242,
#   "        this.events.trigger('kernel_killed.Kernel', {kernel: this});\n"],
#  ['notebook/static/services/kernels/kernel.js',
#   264,
#   "        this.events.trigger('kernel_interrupting.Kernel', {kernel: this});\n"],
#  ['notebook/static/services/kernels/kernel.js',
#   299,
#   "        this.events.trigger('kernel_restarting.Kernel', {kernel: this});\n"],
#  ['notebook/static/services/kernels/kernel.js',
#   304,
#   "            that.events.trigger('kernel_created.Kernel', {kernel: that});\n"],
#  ['notebook/static/services/kernels/kernel.js',
#   312,
#   "            that.events.trigger('kernel_dead.Kernel', {kernel: that});\n"],
#  ['notebook/static/services/kernels/kernel.js',
#   343,
#   "        this.events.trigger('kernel_reconnecting.Kernel', {\n"],
#  ['notebook/static/services/kernels/kernel.js',
#   411,
#   "        this.events.trigger('kernel_connected.Kernel', {kernel: this});\n"],
#  ['notebook/static/services/kernels/kernel.js',
#   416,
#   "            that.events.trigger('kernel_ready.Kernel', {kernel: that});\n"],
#  ['notebook/static/services/kernels/kernel.js',
#   467,
#   "                    that.events.trigger('kernel_dead.Kernel', {kernel: that});\n"],
#  ['notebook/static/services/kernels/kernel.js',
#   525,
#   "        this.events.trigger('kernel_disconnected.Kernel', {kernel: this});\n"],
#  ['notebook/static/services/kernels/kernel.js',
#   528,
#   "            this.events.trigger('kernel_connection_failed.Kernel', {kernel: this, ws_url: ws_url, attempt: this._reconnect_attempt});\n"],
#  ['notebook/static/services/kernels/kernel.js',
#   543,
#   "            this.events.trigger('kernel_connection_dead.Kernel', {\n"],
#  ['notebook/static/services/kernels/kernel.js',
#   748,
#   "        this.events.trigger('execution_request.Kernel', {kernel: this, content: content});\n"],
#  ['notebook/static/services/kernels/kernel.js',
#   786,
#   "        this.events.trigger('input_reply.Kernel', {kernel: this, content: content});\n"],
#  ['notebook/static/services/kernels/kernel.js',
#   905,
#   "        this.events.trigger('shell_reply.Kernel', {kernel: this, reply:reply});\n"],
#  ['notebook/static/services/kernels/kernel.js',
#   967,
#   "            this.events.trigger('kernel_busy.Kernel', {kernel: this});\n"],
#  ['notebook/static/services/kernels/kernel.js',
#   976,
#   "            this.events.trigger('kernel_idle.Kernel', {kernel: this});\n"],
#  ['notebook/static/services/kernels/kernel.js',
#   979,
#   "            this.events.trigger('kernel_starting.Kernel', {kernel: this});\n"],
#  ['notebook/static/services/kernels/kernel.js',
#   983,
#   "                that.events.trigger('kernel_ready.Kernel', {kernel: that});\n"],
#  ['notebook/static/services/kernels/kernel.js',
#   992,
#   "            this.events.trigger('kernel_restarting.Kernel', {kernel: this});\n"],
#  ['notebook/static/services/kernels/kernel.js',
#   993,
#   "            this.events.trigger('kernel_autorestarting.Kernel', {kernel: this, attempt: this._autorestart_attempt});\n"],
#  ['notebook/static/services/kernels/kernel.js',
#   996,
#   "            this.events.trigger('kernel_dead.Kernel', {kernel: this});\n"],
#  ['notebook/static/services/kernels/kernel.js',
#   1027,
#   "            this.events.trigger('received_unsolicited_message.Kernel', msg);\n"],
#  ['notebook/static/services/kernels/kernel.js',
#   1046,
#   "            this.events.trigger('received_unsolicited_message.Kernel', msg);\n"],
#  ['notebook/static/services/sessions/session.js',
#   108,
#   "            that.events.trigger('kernel_created.Session', {session: that, kernel: that.kernel});\n"],
#  ['notebook/static/services/sessions/session.js',
#   115,
#   "            that.events.trigger('kernel_dead.Session', {session: that, xhr: xhr, status: status, error: err});\n"],
#  ['notebook/static/services/sessions/session.js',
#   192,
#   "            this.events.trigger('kernel_killed.Session', {session: this, kernel: this.kernel});\n"],
#  ['notebook/static/tree/js/main.js',
#   148,
#   "    events.trigger('app_initialized.DashboardApp');\n"],
#  ['notebook/static/tree/js/newnotebook.js',
#   73,
#   "        this.events.trigger('kernelspecs_loaded.KernelSpec', data.kernelspecs);\n"],
#  ['notebook/static/tree/js/notebooklist.js',
#   385,
#   "        events.trigger('draw_notebook_list.NotebookList');\n"],
#  ['notebook/static/tree/js/notebooklist.js',
#   956,
#   "                events.trigger('notebook_deleted.NotebookList');\n"],
#  ['notebook/static/tree/js/sessionlist.js',
#   82,
#   "        this.events.trigger('sessions_loaded.Dashboard', this.sessions);\n"]]

# %% [markdown]
# Want:
#
# File name, Line number, Snippet, Decription

# %%
idx = list(range(1,len(results)))
events_trigger = pd.DataFrame(results, columns=['File', 'Line Number', 'Snippet'])

# %%
events_trigger.to_csv('event_triggers.csv')
events_trigger.head()
# Out:
#                                   File  Line Number  \
# 0  notebook/static/base/js/keyboard.js  378
# 1  notebook/static/base/js/keyboard.js  392
# 2  notebook/static/base/js/keyboard.js  413
# 3  notebook/static/edit/js/editor.js    55
# 4  notebook/static/edit/js/editor.js    88
#
#                                                                               Snippet
# 0              this.events.trigger('rebuild.QuickHelp');\n
# 1          this.events.trigger('rebuild.QuickHelp');\n
# 2              this.events.trigger('rebuild.QuickHelp');\n
# 3              that.events.trigger('config_changed.Editor', {config: that.config});\n
# 4                  that.events.trigger("file_loaded.Editor", model);\n

# %%
import pickle
output = open('event_triggers.pkl', 'wb')
pickle.dump(events_trigger, output)
output.close()

# %%
events_trigger
# Out:
#                                              File  Line Number  \
# 0    notebook/static/base/js/keyboard.js           378
# 1    notebook/static/base/js/keyboard.js           392
# 2    notebook/static/base/js/keyboard.js           413
# 3    notebook/static/edit/js/editor.js             55
# 4    notebook/static/edit/js/editor.js             88
# 5    notebook/static/edit/js/editor.js             92
# 6    notebook/static/edit/js/editor.js             133
# 7    notebook/static/edit/js/editor.js             149
# 8    notebook/static/edit/js/editor.js             171
# 9    notebook/static/edit/js/editor.js             173
# 10   notebook/static/edit/js/editor.js             186
# 11   notebook/static/edit/js/editor.js             189
# 12   notebook/static/edit/js/editor.js             215
# 13   notebook/static/notebook/js/actions.js        436
# 14   notebook/static/notebook/js/actions.js        444
# 15   notebook/static/notebook/js/cell.js           171
# 16   notebook/static/notebook/js/cell.js           174
# 17   notebook/static/notebook/js/cell.js           192
# 18   notebook/static/notebook/js/cell.js           198
# 19   notebook/static/notebook/js/cell.js           200
# 20   notebook/static/notebook/js/cell.js           205
# 21   notebook/static/notebook/js/cell.js           211
# 22   notebook/static/notebook/js/cell.js           745
# 23   notebook/static/notebook/js/celltoolbar.js    185
# 24   notebook/static/notebook/js/celltoolbar.js    203
# 25   notebook/static/notebook/js/celltoolbar.js    247
# 26   notebook/static/notebook/js/codecell.js       336
# 27   notebook/static/notebook/js/codecell.js       366
# 28   notebook/static/notebook/js/codecell.js       376
# 29   notebook/static/notebook/js/codecell.js       390
# ..                                       ...       ...
# 80   notebook/static/services/kernels/kernel.js    299
# 81   notebook/static/services/kernels/kernel.js    304
# 82   notebook/static/services/kernels/kernel.js    312
# 83   notebook/static/services/kernels/kernel.js    343
# 84   notebook/static/services/kernels/kernel.js    411
# 85   notebook/static/services/kernels/kernel.js    416
# 86   notebook/static/services/kernels/kernel.js    467
# 87   notebook/static/services/kernels/kernel.js    525
# 88   notebook/static/services/kernels/kernel.js    528
# 89   notebook/static/services/kernels/kernel.js    543
# 90   notebook/static/services/kernels/kernel.js    748
# 91   notebook/static/services/kernels/kernel.js    786
# 92   notebook/static/services/kernels/kernel.js    905
# 93   notebook/static/services/kernels/kernel.js    967
# 94   notebook/static/services/kernels/kernel.js    976
# 95   notebook/static/services/kernels/kernel.js    979
# 96   notebook/static/services/kernels/kernel.js    983
# 97   notebook/static/services/kernels/kernel.js    992
# 98   notebook/static/services/kernels/kernel.js    993
# 99   notebook/static/services/kernels/kernel.js    996
# 100  notebook/static/services/kernels/kernel.js    1027
# 101  notebook/static/services/kernels/kernel.js    1046
# 102  notebook/static/services/sessions/session.js  108
# 103  notebook/static/services/sessions/session.js  115
# 104  notebook/static/services/sessions/session.js  192
# 105  notebook/static/tree/js/main.js               148
# 106  notebook/static/tree/js/newnotebook.js        73
# 107  notebook/static/tree/js/notebooklist.js       385
# 108  notebook/static/tree/js/notebooklist.js       956
# 109  notebook/static/tree/js/sessionlist.js        82
#
#                                                                                                                                      Snippet
# 0                this.events.trigger('rebuild.QuickHelp');\n
# 1            this.events.trigger('rebuild.QuickHelp');\n
# 2                this.events.trigger('rebuild.QuickHelp');\n
# 3                that.events.trigger('config_changed.Editor', {config: that.config});\n
# 4                    that.events.trigger("file_loaded.Editor", model);\n
# 5                    that.events.trigger("file_load_failed.Editor", error);\n
# 6                that.events.trigger("mode_changed.Editor", modeinfo);\n
# 7                    that.events.trigger('file_renamed.Editor', model);\n
# 8            that.events.trigger("file_saving.Editor");\n
# 9                that.events.trigger("file_saved.Editor", data);\n
# 10               this.events.trigger("save_status_clean.Editor");\n
# 11               this.events.trigger("save_status_dirty.Editor");\n
# 12               that.events.trigger('config_changed.Editor', {config: that.config})\n
# 13                   events.trigger('resize-header.Page');\n
# 14                   events.trigger('resize-header.Page');\n
# 15               this.events.trigger('select.Cell', {'cell':this, 'extendSelection':event.shiftKey});\n
# 16               this.events.trigger('select.Cell', {'cell': this});\n
# 17                   that.events.trigger("set_dirty.Notebook", {value: true});\n
# 18                       that.events.trigger('select.Cell', {'cell':that});\n
# 19                   that.events.trigger('edit_mode.Cell', {cell: that});\n
# 20                   that.events.trigger('command_mode.Cell', {cell: that});\n
# 21                   this.events.trigger('select.Cell', {'cell':that});\n
# 22               cell.events.trigger('unrecognized_cell.Cell', {cell: cell});\n
# 23           events.trigger('preset_added.CellToolbar', {name: name});\n
# 24               events.trigger('unregistered_preset.CellToolbar', {name: name});\n
# 25           events.trigger('preset_activated.CellToolbar', {name: preset_name});\n
# 26           this.events.trigger('execute.CodeCell', {cell: this});\n
# 27           this.events.trigger('open_with_text.Pager', payload);\n
# 28           this.events.trigger('set_dirty.Notebook', {value: true});\n
# 29           this.events.trigger('set_next_input.Notebook', data);\n
# ..                                                               ...
# 80           this.events.trigger('kernel_restarting.Kernel', {kernel: this});\n
# 81               that.events.trigger('kernel_created.Kernel', {kernel: that});\n
# 82               that.events.trigger('kernel_dead.Kernel', {kernel: that});\n
# 83           this.events.trigger('kernel_reconnecting.Kernel', {\n
# 84           this.events.trigger('kernel_connected.Kernel', {kernel: this});\n
# 85               that.events.trigger('kernel_ready.Kernel', {kernel: that});\n
# 86                       that.events.trigger('kernel_dead.Kernel', {kernel: that});\n
# 87           this.events.trigger('kernel_disconnected.Kernel', {kernel: this});\n
# 88               this.events.trigger('kernel_connection_failed.Kernel', {kernel: this, ws_url: ws_url, attempt: this._reconnect_attempt});\n
# 89               this.events.trigger('kernel_connection_dead.Kernel', {\n
# 90           this.events.trigger('execution_request.Kernel', {kernel: this, content: content});\n
# 91           this.events.trigger('input_reply.Kernel', {kernel: this, content: content});\n
# 92           this.events.trigger('shell_reply.Kernel', {kernel: this, reply:reply});\n
# 93               this.events.trigger('kernel_busy.Kernel', {kernel: this});\n
# 94               this.events.trigger('kernel_idle.Kernel', {kernel: this});\n
# 95               this.events.trigger('kernel_starting.Kernel', {kernel: this});\n
# 96                   that.events.trigger('kernel_ready.Kernel', {kernel: that});\n
# 97               this.events.trigger('kernel_restarting.Kernel', {kernel: this});\n
# 98               this.events.trigger('kernel_autorestarting.Kernel', {kernel: this, attempt: this._autorestart_attempt});\n
# 99               this.events.trigger('kernel_dead.Kernel', {kernel: this});\n
# 100              this.events.trigger('received_unsolicited_message.Kernel', msg);\n
# 101              this.events.trigger('received_unsolicited_message.Kernel', msg);\n
# 102              that.events.trigger('kernel_created.Session', {session: that, kernel: that.kernel});\n
# 103              that.events.trigger('kernel_dead.Session', {session: that, xhr: xhr, status: status, error: err});\n
# 104              this.events.trigger('kernel_killed.Session', {session: this, kernel: this.kernel});\n
# 105      events.trigger('app_initialized.DashboardApp');\n
# 106          this.events.trigger('kernelspecs_loaded.KernelSpec', data.kernelspecs);\n
# 107          events.trigger('draw_notebook_list.NotebookList');\n
# 108                  events.trigger('notebook_deleted.NotebookList');\n
# 109          this.events.trigger('sessions_loaded.Dashboard', this.sessions);\n
#
# [110 rows x 3 columns]

# %%
events_trigger.to_html("events.html")

# %%
# !ls
# Out:
# bell-ring-01.mp3              jupyter
# error-alert.mp3               jupyter_source_explorer.ipynb
# event_triggers.csv            notebook
# event_triggers.pkl            reader_test_notebook.ipynb
# events.html                   transformer-1.mp3

# %%
# !pwd
# Out:
# /Users/james/Documents/code/thesis-notebooks

# %%
# Base URL: https://github.com/jupyter/notebook/blob/master/
# Example for entry 1: notebook/static/base/js/keyboard.js#L378

# %%
for i in events_trigger.index:
    lineNum = events_trigger['Line Number'][i]
    link_string = "https://github.com/jupyter/notebook/blob/master/" + str(events_trigger['File'][i]) + "#L" + str(lineNum)
    events_trigger['Line Number'][i] = "<a href=\"" + link_string + "\">" + str(lineNum) + "</a>"
# Out:
# //anaconda/lib/python3.4/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# //anaconda/lib/python3.4/site-packages/pandas/core/indexing.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
events_trigger
# Out:
#                                              File  \
# 0    notebook/static/base/js/keyboard.js
# 1    notebook/static/base/js/keyboard.js
# 2    notebook/static/base/js/keyboard.js
# 3    notebook/static/edit/js/editor.js
# 4    notebook/static/edit/js/editor.js
# 5    notebook/static/edit/js/editor.js
# 6    notebook/static/edit/js/editor.js
# 7    notebook/static/edit/js/editor.js
# 8    notebook/static/edit/js/editor.js
# 9    notebook/static/edit/js/editor.js
# 10   notebook/static/edit/js/editor.js
# 11   notebook/static/edit/js/editor.js
# 12   notebook/static/edit/js/editor.js
# 13   notebook/static/notebook/js/actions.js
# 14   notebook/static/notebook/js/actions.js
# 15   notebook/static/notebook/js/cell.js
# 16   notebook/static/notebook/js/cell.js
# 17   notebook/static/notebook/js/cell.js
# 18   notebook/static/notebook/js/cell.js
# 19   notebook/static/notebook/js/cell.js
# 20   notebook/static/notebook/js/cell.js
# 21   notebook/static/notebook/js/cell.js
# 22   notebook/static/notebook/js/cell.js
# 23   notebook/static/notebook/js/celltoolbar.js
# 24   notebook/static/notebook/js/celltoolbar.js
# 25   notebook/static/notebook/js/celltoolbar.js
# 26   notebook/static/notebook/js/codecell.js
# 27   notebook/static/notebook/js/codecell.js
# 28   notebook/static/notebook/js/codecell.js
# 29   notebook/static/notebook/js/codecell.js
# ..                                       ...
# 80   notebook/static/services/kernels/kernel.js
# 81   notebook/static/services/kernels/kernel.js
# 82   notebook/static/services/kernels/kernel.js
# 83   notebook/static/services/kernels/kernel.js
# 84   notebook/static/services/kernels/kernel.js
# 85   notebook/static/services/kernels/kernel.js
# 86   notebook/static/services/kernels/kernel.js
# 87   notebook/static/services/kernels/kernel.js
# 88   notebook/static/services/kernels/kernel.js
# 89   notebook/static/services/kernels/kernel.js
# 90   notebook/static/services/kernels/kernel.js
# 91   notebook/static/services/kernels/kernel.js
# 92   notebook/static/services/kernels/kernel.js
# 93   notebook/static/services/kernels/kernel.js
# 94   notebook/static/services/kernels/kernel.js
# 95   notebook/static/services/kernels/kernel.js
# 96   notebook/static/services/kernels/kernel.js
# 97   notebook/static/services/kernels/kernel.js
# 98   notebook/static/services/kernels/kernel.js
# 99   notebook/static/services/kernels/kernel.js
# 100  notebook/static/services/kernels/kernel.js
# 101  notebook/static/services/kernels/kernel.js
# 102  notebook/static/services/sessions/session.js
# 103  notebook/static/services/sessions/session.js
# 104  notebook/static/services/sessions/session.js
# 105  notebook/static/tree/js/main.js
# 106  notebook/static/tree/js/newnotebook.js
# 107  notebook/static/tree/js/notebooklist.js
# 108  notebook/static/tree/js/notebooklist.js
# 109  notebook/static/tree/js/sessionlist.js
#
#                                                                                                              Line Number  \
# 0    <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/base/js/keyboard.js#L378">378</a>
# 1    <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/base/js/keyboard.js#L392">392</a>
# 2    <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/base/js/keyboard.js#L413">413</a>
# 3    <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/edit/js/editor.js#L55">55</a>
# 4    <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/edit/js/editor.js#L88">88</a>
# 5    <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/edit/js/editor.js#L92">92</a>
# 6    <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/edit/js/editor.js#L133">133</a>
# 7    <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/edit/js/editor.js#L149">149</a>
# 8    <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/edit/js/editor.js#L171">171</a>
# 9    <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/edit/js/editor.js#L173">173</a>
# 10   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/edit/js/editor.js#L186">186</a>
# 11   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/edit/js/editor.js#L189">189</a>
# 12   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/edit/js/editor.js#L215">215</a>
# 13   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/actions.js#L436">436</a>
# 14   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/actions.js#L444">444</a>
# 15   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/cell.js#L171">171</a>
# 16   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/cell.js#L174">174</a>
# 17   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/cell.js#L192">192</a>
# 18   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/cell.js#L198">198</a>
# 19   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/cell.js#L200">200</a>
# 20   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/cell.js#L205">205</a>
# 21   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/cell.js#L211">211</a>
# 22   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/cell.js#L745">745</a>
# 23   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/celltoolbar.js#L185">185</a>
# 24   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/celltoolbar.js#L203">203</a>
# 25   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/celltoolbar.js#L247">247</a>
# 26   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/codecell.js#L336">336</a>
# 27   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/codecell.js#L366">366</a>
# 28   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/codecell.js#L376">376</a>
# 29   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/codecell.js#L390">390</a>
# ..                                                                                                              ...
# 80   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L299">299</a>
# 81   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L304">304</a>
# 82   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L312">312</a>
# 83   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L343">343</a>
# 84   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L411">411</a>
# 85   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L416">416</a>
# 86   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L467">467</a>
# 87   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L525">525</a>
# 88   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L528">528</a>
# 89   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L543">543</a>
# 90   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L748">748</a>
# 91   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L786">786</a>
# 92   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L905">905</a>
# 93   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L967">967</a>
# 94   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L976">976</a>
# 95   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L979">979</a>
# 96   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L983">983</a>
# 97   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L992">992</a>
# 98   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L993">993</a>
# 99   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L996">996</a>
# 100  <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L1027">1027</a>
# 101  <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L1046">1046</a>
# 102  <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/sessions/session.js#L108">108</a>
# 103  <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/sessions/session.js#L115">115</a>
# 104  <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/sessions/session.js#L192">192</a>
# 105  <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/tree/js/main.js#L148">148</a>
# 106  <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/tree/js/newnotebook.js#L73">73</a>
# 107  <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/tree/js/notebooklist.js#L385">385</a>
# 108  <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/tree/js/notebooklist.js#L956">956</a>
# 109  <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/tree/js/sessionlist.js#L82">82</a>
#
#                                                                                                                                      Snippet
# 0                this.events.trigger('rebuild.QuickHelp');\n
# 1            this.events.trigger('rebuild.QuickHelp');\n
# 2                this.events.trigger('rebuild.QuickHelp');\n
# 3                that.events.trigger('config_changed.Editor', {config: that.config});\n
# 4                    that.events.trigger("file_loaded.Editor", model);\n
# 5                    that.events.trigger("file_load_failed.Editor", error);\n
# 6                that.events.trigger("mode_changed.Editor", modeinfo);\n
# 7                    that.events.trigger('file_renamed.Editor', model);\n
# 8            that.events.trigger("file_saving.Editor");\n
# 9                that.events.trigger("file_saved.Editor", data);\n
# 10               this.events.trigger("save_status_clean.Editor");\n
# 11               this.events.trigger("save_status_dirty.Editor");\n
# 12               that.events.trigger('config_changed.Editor', {config: that.config})\n
# 13                   events.trigger('resize-header.Page');\n
# 14                   events.trigger('resize-header.Page');\n
# 15               this.events.trigger('select.Cell', {'cell':this, 'extendSelection':event.shiftKey});\n
# 16               this.events.trigger('select.Cell', {'cell': this});\n
# 17                   that.events.trigger("set_dirty.Notebook", {value: true});\n
# 18                       that.events.trigger('select.Cell', {'cell':that});\n
# 19                   that.events.trigger('edit_mode.Cell', {cell: that});\n
# 20                   that.events.trigger('command_mode.Cell', {cell: that});\n
# 21                   this.events.trigger('select.Cell', {'cell':that});\n
# 22               cell.events.trigger('unrecognized_cell.Cell', {cell: cell});\n
# 23           events.trigger('preset_added.CellToolbar', {name: name});\n
# 24               events.trigger('unregistered_preset.CellToolbar', {name: name});\n
# 25           events.trigger('preset_activated.CellToolbar', {name: preset_name});\n
# 26           this.events.trigger('execute.CodeCell', {cell: this});\n
# 27           this.events.trigger('open_with_text.Pager', payload);\n
# 28           this.events.trigger('set_dirty.Notebook', {value: true});\n
# 29           this.events.trigger('set_next_input.Notebook', data);\n
# ..                                                               ...
# 80           this.events.trigger('kernel_restarting.Kernel', {kernel: this});\n
# 81               that.events.trigger('kernel_created.Kernel', {kernel: that});\n
# 82               that.events.trigger('kernel_dead.Kernel', {kernel: that});\n
# 83           this.events.trigger('kernel_reconnecting.Kernel', {\n
# 84           this.events.trigger('kernel_connected.Kernel', {kernel: this});\n
# 85               that.events.trigger('kernel_ready.Kernel', {kernel: that});\n
# 86                       that.events.trigger('kernel_dead.Kernel', {kernel: that});\n
# 87           this.events.trigger('kernel_disconnected.Kernel', {kernel: this});\n
# 88               this.events.trigger('kernel_connection_failed.Kernel', {kernel: this, ws_url: ws_url, attempt: this._reconnect_attempt});\n
# 89               this.events.trigger('kernel_connection_dead.Kernel', {\n
# 90           this.events.trigger('execution_request.Kernel', {kernel: this, content: content});\n
# 91           this.events.trigger('input_reply.Kernel', {kernel: this, content: content});\n
# 92           this.events.trigger('shell_reply.Kernel', {kernel: this, reply:reply});\n
# 93               this.events.trigger('kernel_busy.Kernel', {kernel: this});\n
# 94               this.events.trigger('kernel_idle.Kernel', {kernel: this});\n
# 95               this.events.trigger('kernel_starting.Kernel', {kernel: this});\n
# 96                   that.events.trigger('kernel_ready.Kernel', {kernel: that});\n
# 97               this.events.trigger('kernel_restarting.Kernel', {kernel: this});\n
# 98               this.events.trigger('kernel_autorestarting.Kernel', {kernel: this, attempt: this._autorestart_attempt});\n
# 99               this.events.trigger('kernel_dead.Kernel', {kernel: this});\n
# 100              this.events.trigger('received_unsolicited_message.Kernel', msg);\n
# 101              this.events.trigger('received_unsolicited_message.Kernel', msg);\n
# 102              that.events.trigger('kernel_created.Session', {session: that, kernel: that.kernel});\n
# 103              that.events.trigger('kernel_dead.Session', {session: that, xhr: xhr, status: status, error: err});\n
# 104              this.events.trigger('kernel_killed.Session', {session: this, kernel: this.kernel});\n
# 105      events.trigger('app_initialized.DashboardApp');\n
# 106          this.events.trigger('kernelspecs_loaded.KernelSpec', data.kernelspecs);\n
# 107          events.trigger('draw_notebook_list.NotebookList');\n
# 108                  events.trigger('notebook_deleted.NotebookList');\n
# 109          this.events.trigger('sessions_loaded.Dashboard', this.sessions);\n
#
# [110 rows x 3 columns]

# %%
pd.set_option('display.max_colwidth', -1)
events_trigger.to_html("events.html")
