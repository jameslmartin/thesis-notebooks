# %%
import re
import os
import pandas as pd
import glob
import pandas
import mmap
import ntpath

# %%
# !ls
# Out:
# jupyter                       notebook
# jupyter_source_explorer.ipynb reader_test_notebook.ipynb

# %%
os.chdir("./jupyter")

# %%
files_to_be_searched = []

for path, subdirs, files in os.walk(r'/Users/james/Documents/code/thesis-notebooks/notebook/'):
    for filename in files:
        if filename.endswith('.js') or filename.endswith('.py'):
            files_to_be_searched.append(os.path.join(path, filename))

# %%
len(files_to_be_searched)
# Out:
# 201

# %%
# Note: search_term needs to be in byte format, easiest (only?) way to do this is to prefix the string with a 'b'
def search_files_for_term(search_term, files_to_be_searched):
    narrowed_files = []
    # Narrow down files
    for file in files_to_be_searched:
        if os.stat(file).st_size != 0: # If file is not empty
            open_file = open(file,'r')
            # Create a memory map for easy searching
            mem_map = mmap.mmap(open_file.fileno(), 0, access=mmap.ACCESS_READ)
            if mem_map.find(search_term) != -1:
                 narrowed_files.append(file)
                    
    # Search files for lines containing search term    
    search_results = []
    for file in narrowed_files:
        #head, tail = ntpath.split(file)
        file_path = file.split('thesis-notebooks/notebook/')[1]
        search_term_as_string = search_term.decode('utf-8')
        line_tuples = get_line_number_and_string(search_term_as_string, file)

        for line in line_tuples:
            search_results.append([file_path,line[0],line[1]])
            
    return search_results

# %%
def get_line_number_and_string(search_term, filename):
    line_numbers = []
    with open(filename) as f:
        for num, line in enumerate(f, 1):
            if str(search_term) in line:
                line_numbers.append((num,line))
    return line_numbers

# %%
search_term = b'events.trigger'

results = search_files_for_term(search_term, files_to_be_searched)

# %%
#results

# %% [markdown]
# Want:
#
# File name, Line number, Snippet, Decription

# %%
idx = list(range(1,len(results)))
events_trigger = pd.DataFrame(results, columns=['File', 'Line Number', 'Snippet'])

# %%
events_trigger.to_csv('event_triggers.csv')
events_trigger.head()
# Out:
#                                   File  Line Number  \
# 0  notebook/static/base/js/keyboard.js          378
# 1  notebook/static/base/js/keyboard.js          392
# 2  notebook/static/base/js/keyboard.js          413
# 3    notebook/static/edit/js/editor.js           55
# 4    notebook/static/edit/js/editor.js           88
#
#                                              Snippet
# 0              this.events.trigger('rebuild.Quick...
# 1          this.events.trigger('rebuild.QuickHelp...
# 2              this.events.trigger('rebuild.Quick...
# 3              that.events.trigger('config_change...
# 4                  that.events.trigger("file_load...

# %%
import pickle
output = open('event_triggers.pkl', 'wb')
pickle.dump(events_trigger, output)
output.close()

# %%
events_trigger
# Out:
#                                              File  Line Number  \
# 0             notebook/static/base/js/keyboard.js          378
# 1             notebook/static/base/js/keyboard.js          392
# 2             notebook/static/base/js/keyboard.js          413
# 3               notebook/static/edit/js/editor.js           55
# 4               notebook/static/edit/js/editor.js           88
# 5               notebook/static/edit/js/editor.js           92
# 6               notebook/static/edit/js/editor.js          132
# 7               notebook/static/edit/js/editor.js          148
# 8               notebook/static/edit/js/editor.js          170
# 9               notebook/static/edit/js/editor.js          172
# 10              notebook/static/edit/js/editor.js          185
# 11              notebook/static/edit/js/editor.js          188
# 12              notebook/static/edit/js/editor.js          214
# 13         notebook/static/notebook/js/actions.js          432
# 14         notebook/static/notebook/js/actions.js          440
# 15            notebook/static/notebook/js/cell.js          165
# 16            notebook/static/notebook/js/cell.js          168
# 17            notebook/static/notebook/js/cell.js          186
# 18            notebook/static/notebook/js/cell.js          192
# 19            notebook/static/notebook/js/cell.js          194
# 20            notebook/static/notebook/js/cell.js          199
# 21            notebook/static/notebook/js/cell.js          205
# 22            notebook/static/notebook/js/cell.js          739
# 23     notebook/static/notebook/js/celltoolbar.js          185
# 24     notebook/static/notebook/js/celltoolbar.js          203
# 25     notebook/static/notebook/js/celltoolbar.js          247
# 26        notebook/static/notebook/js/codecell.js          340
# 27        notebook/static/notebook/js/codecell.js          370
# 28        notebook/static/notebook/js/codecell.js          380
# 29        notebook/static/notebook/js/codecell.js          394
# ..                                            ...          ...
# 80     notebook/static/services/kernels/kernel.js          299
# 81     notebook/static/services/kernels/kernel.js          304
# 82     notebook/static/services/kernels/kernel.js          312
# 83     notebook/static/services/kernels/kernel.js          343
# 84     notebook/static/services/kernels/kernel.js          411
# 85     notebook/static/services/kernels/kernel.js          416
# 86     notebook/static/services/kernels/kernel.js          467
# 87     notebook/static/services/kernels/kernel.js          525
# 88     notebook/static/services/kernels/kernel.js          528
# 89     notebook/static/services/kernels/kernel.js          543
# 90     notebook/static/services/kernels/kernel.js          748
# 91     notebook/static/services/kernels/kernel.js          786
# 92     notebook/static/services/kernels/kernel.js          905
# 93     notebook/static/services/kernels/kernel.js          967
# 94     notebook/static/services/kernels/kernel.js          976
# 95     notebook/static/services/kernels/kernel.js          979
# 96     notebook/static/services/kernels/kernel.js          983
# 97     notebook/static/services/kernels/kernel.js          992
# 98     notebook/static/services/kernels/kernel.js          993
# 99     notebook/static/services/kernels/kernel.js          996
# 100    notebook/static/services/kernels/kernel.js         1027
# 101    notebook/static/services/kernels/kernel.js         1046
# 102  notebook/static/services/sessions/session.js          108
# 103  notebook/static/services/sessions/session.js          115
# 104  notebook/static/services/sessions/session.js          192
# 105               notebook/static/tree/js/main.js          148
# 106        notebook/static/tree/js/newnotebook.js           73
# 107       notebook/static/tree/js/notebooklist.js          384
# 108       notebook/static/tree/js/notebooklist.js          871
# 109        notebook/static/tree/js/sessionlist.js           82
#
#                                                Snippet
# 0                this.events.trigger('rebuild.Quick...
# 1            this.events.trigger('rebuild.QuickHelp...
# 2                this.events.trigger('rebuild.Quick...
# 3                that.events.trigger('config_change...
# 4                    that.events.trigger("file_load...
# 5                    that.events.trigger("file_load...
# 6                that.events.trigger("mode_changed....
# 7                    that.events.trigger('file_rena...
# 8            that.events.trigger("file_saving.Edito...
# 9                that.events.trigger("file_saved.Ed...
# 10               this.events.trigger("save_status_c...
# 11               this.events.trigger("save_status_d...
# 12               that.events.trigger('config_change...
# 13                   events.trigger('resize-header....
# 14                   events.trigger('resize-header....
# 15               this.events.trigger('select.Cell',...
# 16               this.events.trigger('select.Cell',...
# 17                   that.events.trigger("set_dirty...
# 18                       that.events.trigger('selec...
# 19                   that.events.trigger('edit_mode...
# 20                   that.events.trigger('command_m...
# 21                   this.events.trigger('select.Ce...
# 22               cell.events.trigger('unrecognized_...
# 23           events.trigger('preset_added.CellToolb...
# 24               events.trigger('unregistered_prese...
# 25           events.trigger('preset_activated.CellT...
# 26           this.events.trigger('execute.CodeCell'...
# 27           this.events.trigger('open_with_text.Pa...
# 28           this.events.trigger('set_dirty.Noteboo...
# 29           this.events.trigger('set_next_input.No...
# ..                                                 ...
# 80           this.events.trigger('kernel_restarting...
# 81               that.events.trigger('kernel_create...
# 82               that.events.trigger('kernel_dead.K...
# 83           this.events.trigger('kernel_reconnecti...
# 84           this.events.trigger('kernel_connected....
# 85               that.events.trigger('kernel_ready....
# 86                       that.events.trigger('kerne...
# 87           this.events.trigger('kernel_disconnect...
# 88               this.events.trigger('kernel_connec...
# 89               this.events.trigger('kernel_connec...
# 90           this.events.trigger('execution_request...
# 91           this.events.trigger('input_reply.Kerne...
# 92           this.events.trigger('shell_reply.Kerne...
# 93               this.events.trigger('kernel_busy.K...
# 94               this.events.trigger('kernel_idle.K...
# 95               this.events.trigger('kernel_starti...
# 96                   that.events.trigger('kernel_re...
# 97               this.events.trigger('kernel_restar...
# 98               this.events.trigger('kernel_autore...
# 99               this.events.trigger('kernel_dead.K...
# 100              this.events.trigger('received_unso...
# 101              this.events.trigger('received_unso...
# 102              that.events.trigger('kernel_create...
# 103              that.events.trigger('kernel_dead.S...
# 104              this.events.trigger('kernel_killed...
# 105      events.trigger('app_initialized.DashboardA...
# 106          this.events.trigger('kernelspecs_loade...
# 107          events.trigger('draw_notebook_list.Not...
# 108                  events.trigger('notebook_delet...
# 109          this.events.trigger('sessions_loaded.D...
#
# [110 rows x 3 columns]
