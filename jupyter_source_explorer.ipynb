# %%
import re
import os
import pandas as pd
import glob
import pandas
import mmap
import ntpath

# %%
# !ls
# Out:
# bell-ring-01.mp3              event_triggers.pkl            jupyter_source_explorer.ipynb transformer-1.mp3
# error-alert.mp3               events.html                   notebook
# event_triggers.csv            jupyter                       reader_test_notebook.ipynb

# %%
#os.chdir("./jupyter")

# %%
files_to_be_searched = []

for path, subdirs, files in os.walk(r'/Users/james/Documents/code/thesis-notebooks/notebook/'):
    for filename in files:
        if filename.endswith('.js') or filename.endswith('.py'):
            files_to_be_searched.append(os.path.join(path, filename))

# %%
len(files_to_be_searched)
# Out:
# 201

# %%
# Note: search_term needs to be in byte format, easiest (only?) way to do this is to prefix the string with a 'b'
def search_files_for_term(search_term, files_to_be_searched):
    narrowed_files = []
    # Narrow down files
    for file in files_to_be_searched:
        if os.stat(file).st_size != 0: # If file is not empty
            open_file = open(file,'r')
            # Create a memory map for easy searching
            mem_map = mmap.mmap(open_file.fileno(), 0, access=mmap.ACCESS_READ)
            if mem_map.find(search_term) != -1:
                 narrowed_files.append(file)
                    
    # Search files for lines containing search term    
    search_results = []
    for file in narrowed_files:
        #head, tail = ntpath.split(file)
        file_path = file.split('thesis-notebooks/notebook/')[1]
        search_term_as_string = search_term.decode('utf-8')
        line_tuples = get_line_number_and_string(search_term_as_string, file)

        for line in line_tuples:
            search_results.append([file_path,line[0],line[1]])
            
    return search_results

# %%
def get_line_number_and_string(search_term, filename):
    line_numbers = []
    with open(filename) as f:
        #line_number = 0
        lines = f.readlines()
        for line_num, line_text in enumerate(lines):
            if str(search_term) in line_text:
                line_numbers.append((line_num,line_text))
    f.close()
    return line_numbers

# %%
search_term = b'events.trigger'

results = search_files_for_term(search_term, files_to_be_searched)

# %%
#results

# %% [markdown]
# Want:
#
# File name, Line number, Snippet, Decription

# %%
idx = list(range(1,len(results)))
events_trigger = pd.DataFrame(results, columns=['File', 'Line Number', 'Snippet'])

# %%
events_trigger.to_csv('event_triggers.csv')
events_trigger.head()
# Out:
#                                   File  Line Number  \
# 0  notebook/static/base/js/keyboard.js  377
# 1  notebook/static/base/js/keyboard.js  391
# 2  notebook/static/base/js/keyboard.js  412
# 3  notebook/static/edit/js/editor.js    54
# 4  notebook/static/edit/js/editor.js    87
#
#                                                                               Snippet
# 0              this.events.trigger('rebuild.QuickHelp');\n
# 1          this.events.trigger('rebuild.QuickHelp');\n
# 2              this.events.trigger('rebuild.QuickHelp');\n
# 3              that.events.trigger('config_changed.Editor', {config: that.config});\n
# 4                  that.events.trigger("file_loaded.Editor", model);\n

# %%
import pickle
output = open('event_triggers.pkl', 'wb')
pickle.dump(events_trigger, output)
output.close()

# %%
events_trigger
# Out:
#                                              File  Line Number  \
# 0    notebook/static/base/js/keyboard.js           377
# 1    notebook/static/base/js/keyboard.js           391
# 2    notebook/static/base/js/keyboard.js           412
# 3    notebook/static/edit/js/editor.js             54
# 4    notebook/static/edit/js/editor.js             87
# 5    notebook/static/edit/js/editor.js             91
# 6    notebook/static/edit/js/editor.js             132
# 7    notebook/static/edit/js/editor.js             148
# 8    notebook/static/edit/js/editor.js             170
# 9    notebook/static/edit/js/editor.js             172
# 10   notebook/static/edit/js/editor.js             185
# 11   notebook/static/edit/js/editor.js             188
# 12   notebook/static/edit/js/editor.js             214
# 13   notebook/static/notebook/js/actions.js        431
# 14   notebook/static/notebook/js/actions.js        439
# 15   notebook/static/notebook/js/cell.js           164
# 16   notebook/static/notebook/js/cell.js           167
# 17   notebook/static/notebook/js/cell.js           185
# 18   notebook/static/notebook/js/cell.js           191
# 19   notebook/static/notebook/js/cell.js           193
# 20   notebook/static/notebook/js/cell.js           198
# 21   notebook/static/notebook/js/cell.js           204
# 22   notebook/static/notebook/js/cell.js           738
# 23   notebook/static/notebook/js/celltoolbar.js    184
# 24   notebook/static/notebook/js/celltoolbar.js    202
# 25   notebook/static/notebook/js/celltoolbar.js    246
# 26   notebook/static/notebook/js/codecell.js       339
# 27   notebook/static/notebook/js/codecell.js       369
# 28   notebook/static/notebook/js/codecell.js       379
# 29   notebook/static/notebook/js/codecell.js       393
# ..                                       ...       ...
# 80   notebook/static/services/kernels/kernel.js    298
# 81   notebook/static/services/kernels/kernel.js    303
# 82   notebook/static/services/kernels/kernel.js    311
# 83   notebook/static/services/kernels/kernel.js    342
# 84   notebook/static/services/kernels/kernel.js    410
# 85   notebook/static/services/kernels/kernel.js    415
# 86   notebook/static/services/kernels/kernel.js    466
# 87   notebook/static/services/kernels/kernel.js    524
# 88   notebook/static/services/kernels/kernel.js    527
# 89   notebook/static/services/kernels/kernel.js    542
# 90   notebook/static/services/kernels/kernel.js    747
# 91   notebook/static/services/kernels/kernel.js    785
# 92   notebook/static/services/kernels/kernel.js    904
# 93   notebook/static/services/kernels/kernel.js    966
# 94   notebook/static/services/kernels/kernel.js    975
# 95   notebook/static/services/kernels/kernel.js    978
# 96   notebook/static/services/kernels/kernel.js    982
# 97   notebook/static/services/kernels/kernel.js    991
# 98   notebook/static/services/kernels/kernel.js    992
# 99   notebook/static/services/kernels/kernel.js    995
# 100  notebook/static/services/kernels/kernel.js    1026
# 101  notebook/static/services/kernels/kernel.js    1045
# 102  notebook/static/services/sessions/session.js  107
# 103  notebook/static/services/sessions/session.js  114
# 104  notebook/static/services/sessions/session.js  191
# 105  notebook/static/tree/js/main.js               147
# 106  notebook/static/tree/js/newnotebook.js        72
# 107  notebook/static/tree/js/notebooklist.js       383
# 108  notebook/static/tree/js/notebooklist.js       870
# 109  notebook/static/tree/js/sessionlist.js        81
#
#                                                                                                                                      Snippet
# 0                this.events.trigger('rebuild.QuickHelp');\n
# 1            this.events.trigger('rebuild.QuickHelp');\n
# 2                this.events.trigger('rebuild.QuickHelp');\n
# 3                that.events.trigger('config_changed.Editor', {config: that.config});\n
# 4                    that.events.trigger("file_loaded.Editor", model);\n
# 5                    that.events.trigger("file_load_failed.Editor", error);\n
# 6                that.events.trigger("mode_changed.Editor", modeinfo);\n
# 7                    that.events.trigger('file_renamed.Editor', model);\n
# 8            that.events.trigger("file_saving.Editor");\n
# 9                that.events.trigger("file_saved.Editor", data);\n
# 10               this.events.trigger("save_status_clean.Editor");\n
# 11               this.events.trigger("save_status_dirty.Editor");\n
# 12               that.events.trigger('config_changed.Editor', {config: that.config})\n
# 13                   events.trigger('resize-header.Page');\n
# 14                   events.trigger('resize-header.Page');\n
# 15               this.events.trigger('select.Cell', {'cell':this, 'extendSelection':event.shiftKey});\n
# 16               this.events.trigger('select.Cell', {'cell': this});\n
# 17                   that.events.trigger("set_dirty.Notebook", {value: true});\n
# 18                       that.events.trigger('select.Cell', {'cell':that});\n
# 19                   that.events.trigger('edit_mode.Cell', {cell: that});\n
# 20                   that.events.trigger('command_mode.Cell', {cell: that});\n
# 21                   this.events.trigger('select.Cell', {'cell':that});\n
# 22               cell.events.trigger('unrecognized_cell.Cell', {cell: cell});\n
# 23           events.trigger('preset_added.CellToolbar', {name: name});\n
# 24               events.trigger('unregistered_preset.CellToolbar', {name: name});\n
# 25           events.trigger('preset_activated.CellToolbar', {name: preset_name});\n
# 26           this.events.trigger('execute.CodeCell', {cell: this});\n
# 27           this.events.trigger('open_with_text.Pager', payload);\n
# 28           this.events.trigger('set_dirty.Notebook', {value: true});\n
# 29           this.events.trigger('set_next_input.Notebook', data);\n
# ..                                                               ...
# 80           this.events.trigger('kernel_restarting.Kernel', {kernel: this});\n
# 81               that.events.trigger('kernel_created.Kernel', {kernel: that});\n
# 82               that.events.trigger('kernel_dead.Kernel', {kernel: that});\n
# 83           this.events.trigger('kernel_reconnecting.Kernel', {\n
# 84           this.events.trigger('kernel_connected.Kernel', {kernel: this});\n
# 85               that.events.trigger('kernel_ready.Kernel', {kernel: that});\n
# 86                       that.events.trigger('kernel_dead.Kernel', {kernel: that});\n
# 87           this.events.trigger('kernel_disconnected.Kernel', {kernel: this});\n
# 88               this.events.trigger('kernel_connection_failed.Kernel', {kernel: this, ws_url: ws_url, attempt: this._reconnect_attempt});\n
# 89               this.events.trigger('kernel_connection_dead.Kernel', {\n
# 90           this.events.trigger('execution_request.Kernel', {kernel: this, content: content});\n
# 91           this.events.trigger('input_reply.Kernel', {kernel: this, content: content});\n
# 92           this.events.trigger('shell_reply.Kernel', {kernel: this, reply:reply});\n
# 93               this.events.trigger('kernel_busy.Kernel', {kernel: this});\n
# 94               this.events.trigger('kernel_idle.Kernel', {kernel: this});\n
# 95               this.events.trigger('kernel_starting.Kernel', {kernel: this});\n
# 96                   that.events.trigger('kernel_ready.Kernel', {kernel: that});\n
# 97               this.events.trigger('kernel_restarting.Kernel', {kernel: this});\n
# 98               this.events.trigger('kernel_autorestarting.Kernel', {kernel: this, attempt: this._autorestart_attempt});\n
# 99               this.events.trigger('kernel_dead.Kernel', {kernel: this});\n
# 100              this.events.trigger('received_unsolicited_message.Kernel', msg);\n
# 101              this.events.trigger('received_unsolicited_message.Kernel', msg);\n
# 102              that.events.trigger('kernel_created.Session', {session: that, kernel: that.kernel});\n
# 103              that.events.trigger('kernel_dead.Session', {session: that, xhr: xhr, status: status, error: err});\n
# 104              this.events.trigger('kernel_killed.Session', {session: this, kernel: this.kernel});\n
# 105      events.trigger('app_initialized.DashboardApp');\n
# 106          this.events.trigger('kernelspecs_loaded.KernelSpec', data.kernelspecs);\n
# 107          events.trigger('draw_notebook_list.NotebookList');\n
# 108                  events.trigger('notebook_deleted.NotebookList');\n
# 109          this.events.trigger('sessions_loaded.Dashboard', this.sessions);\n
#
# [110 rows x 3 columns]

# %%
events_trigger.to_html("events.html")

# %%
# !ls
# Out:
# bell-ring-01.mp3              event_triggers.pkl            jupyter_source_explorer.ipynb transformer-1.mp3
# error-alert.mp3               events.html                   notebook
# event_triggers.csv            jupyter                       reader_test_notebook.ipynb

# %%
# !pwd
# Out:
# /Users/james/Documents/code/thesis-notebooks

# %%
# Base URL: https://github.com/jupyter/notebook/blob/master/
# Example for entry 1: notebook/static/base/js/keyboard.js#L378

# %%
for i in events_trigger.index:
    lineNum = events_trigger['Line Number'][i]
    link_string = "https://github.com/jupyter/notebook/blob/master/" + str(events_trigger['File'][i]) + "#L" + str(lineNum)
    events_trigger['Line Number'][i] = "<a href=\"" + link_string + "\">" + str(lineNum) + "</a>"
# Out:
# //anaconda/lib/python3.4/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# //anaconda/lib/python3.4/site-packages/pandas/core/indexing.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
events_trigger
# Out:
#                                              File  \
# 0    notebook/static/base/js/keyboard.js
# 1    notebook/static/base/js/keyboard.js
# 2    notebook/static/base/js/keyboard.js
# 3    notebook/static/edit/js/editor.js
# 4    notebook/static/edit/js/editor.js
# 5    notebook/static/edit/js/editor.js
# 6    notebook/static/edit/js/editor.js
# 7    notebook/static/edit/js/editor.js
# 8    notebook/static/edit/js/editor.js
# 9    notebook/static/edit/js/editor.js
# 10   notebook/static/edit/js/editor.js
# 11   notebook/static/edit/js/editor.js
# 12   notebook/static/edit/js/editor.js
# 13   notebook/static/notebook/js/actions.js
# 14   notebook/static/notebook/js/actions.js
# 15   notebook/static/notebook/js/cell.js
# 16   notebook/static/notebook/js/cell.js
# 17   notebook/static/notebook/js/cell.js
# 18   notebook/static/notebook/js/cell.js
# 19   notebook/static/notebook/js/cell.js
# 20   notebook/static/notebook/js/cell.js
# 21   notebook/static/notebook/js/cell.js
# 22   notebook/static/notebook/js/cell.js
# 23   notebook/static/notebook/js/celltoolbar.js
# 24   notebook/static/notebook/js/celltoolbar.js
# 25   notebook/static/notebook/js/celltoolbar.js
# 26   notebook/static/notebook/js/codecell.js
# 27   notebook/static/notebook/js/codecell.js
# 28   notebook/static/notebook/js/codecell.js
# 29   notebook/static/notebook/js/codecell.js
# ..                                       ...
# 80   notebook/static/services/kernels/kernel.js
# 81   notebook/static/services/kernels/kernel.js
# 82   notebook/static/services/kernels/kernel.js
# 83   notebook/static/services/kernels/kernel.js
# 84   notebook/static/services/kernels/kernel.js
# 85   notebook/static/services/kernels/kernel.js
# 86   notebook/static/services/kernels/kernel.js
# 87   notebook/static/services/kernels/kernel.js
# 88   notebook/static/services/kernels/kernel.js
# 89   notebook/static/services/kernels/kernel.js
# 90   notebook/static/services/kernels/kernel.js
# 91   notebook/static/services/kernels/kernel.js
# 92   notebook/static/services/kernels/kernel.js
# 93   notebook/static/services/kernels/kernel.js
# 94   notebook/static/services/kernels/kernel.js
# 95   notebook/static/services/kernels/kernel.js
# 96   notebook/static/services/kernels/kernel.js
# 97   notebook/static/services/kernels/kernel.js
# 98   notebook/static/services/kernels/kernel.js
# 99   notebook/static/services/kernels/kernel.js
# 100  notebook/static/services/kernels/kernel.js
# 101  notebook/static/services/kernels/kernel.js
# 102  notebook/static/services/sessions/session.js
# 103  notebook/static/services/sessions/session.js
# 104  notebook/static/services/sessions/session.js
# 105  notebook/static/tree/js/main.js
# 106  notebook/static/tree/js/newnotebook.js
# 107  notebook/static/tree/js/notebooklist.js
# 108  notebook/static/tree/js/notebooklist.js
# 109  notebook/static/tree/js/sessionlist.js
#
#                                                                                                              Line Number  \
# 0    <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/base/js/keyboard.js#L377">377</a>
# 1    <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/base/js/keyboard.js#L391">391</a>
# 2    <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/base/js/keyboard.js#L412">412</a>
# 3    <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/edit/js/editor.js#L54">54</a>
# 4    <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/edit/js/editor.js#L87">87</a>
# 5    <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/edit/js/editor.js#L91">91</a>
# 6    <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/edit/js/editor.js#L132">132</a>
# 7    <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/edit/js/editor.js#L148">148</a>
# 8    <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/edit/js/editor.js#L170">170</a>
# 9    <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/edit/js/editor.js#L172">172</a>
# 10   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/edit/js/editor.js#L185">185</a>
# 11   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/edit/js/editor.js#L188">188</a>
# 12   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/edit/js/editor.js#L214">214</a>
# 13   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/actions.js#L431">431</a>
# 14   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/actions.js#L439">439</a>
# 15   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/cell.js#L164">164</a>
# 16   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/cell.js#L167">167</a>
# 17   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/cell.js#L185">185</a>
# 18   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/cell.js#L191">191</a>
# 19   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/cell.js#L193">193</a>
# 20   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/cell.js#L198">198</a>
# 21   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/cell.js#L204">204</a>
# 22   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/cell.js#L738">738</a>
# 23   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/celltoolbar.js#L184">184</a>
# 24   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/celltoolbar.js#L202">202</a>
# 25   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/celltoolbar.js#L246">246</a>
# 26   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/codecell.js#L339">339</a>
# 27   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/codecell.js#L369">369</a>
# 28   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/codecell.js#L379">379</a>
# 29   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/notebook/js/codecell.js#L393">393</a>
# ..                                                                                                              ...
# 80   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L298">298</a>
# 81   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L303">303</a>
# 82   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L311">311</a>
# 83   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L342">342</a>
# 84   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L410">410</a>
# 85   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L415">415</a>
# 86   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L466">466</a>
# 87   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L524">524</a>
# 88   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L527">527</a>
# 89   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L542">542</a>
# 90   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L747">747</a>
# 91   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L785">785</a>
# 92   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L904">904</a>
# 93   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L966">966</a>
# 94   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L975">975</a>
# 95   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L978">978</a>
# 96   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L982">982</a>
# 97   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L991">991</a>
# 98   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L992">992</a>
# 99   <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L995">995</a>
# 100  <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L1026">1026</a>
# 101  <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/kernels/kernel.js#L1045">1045</a>
# 102  <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/sessions/session.js#L107">107</a>
# 103  <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/sessions/session.js#L114">114</a>
# 104  <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/services/sessions/session.js#L191">191</a>
# 105  <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/tree/js/main.js#L147">147</a>
# 106  <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/tree/js/newnotebook.js#L72">72</a>
# 107  <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/tree/js/notebooklist.js#L383">383</a>
# 108  <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/tree/js/notebooklist.js#L870">870</a>
# 109  <a href="https://github.com/jupyter/notebook/blob/master/notebook/static/tree/js/sessionlist.js#L81">81</a>
#
#                                                                                                                                      Snippet
# 0                this.events.trigger('rebuild.QuickHelp');\n
# 1            this.events.trigger('rebuild.QuickHelp');\n
# 2                this.events.trigger('rebuild.QuickHelp');\n
# 3                that.events.trigger('config_changed.Editor', {config: that.config});\n
# 4                    that.events.trigger("file_loaded.Editor", model);\n
# 5                    that.events.trigger("file_load_failed.Editor", error);\n
# 6                that.events.trigger("mode_changed.Editor", modeinfo);\n
# 7                    that.events.trigger('file_renamed.Editor', model);\n
# 8            that.events.trigger("file_saving.Editor");\n
# 9                that.events.trigger("file_saved.Editor", data);\n
# 10               this.events.trigger("save_status_clean.Editor");\n
# 11               this.events.trigger("save_status_dirty.Editor");\n
# 12               that.events.trigger('config_changed.Editor', {config: that.config})\n
# 13                   events.trigger('resize-header.Page');\n
# 14                   events.trigger('resize-header.Page');\n
# 15               this.events.trigger('select.Cell', {'cell':this, 'extendSelection':event.shiftKey});\n
# 16               this.events.trigger('select.Cell', {'cell': this});\n
# 17                   that.events.trigger("set_dirty.Notebook", {value: true});\n
# 18                       that.events.trigger('select.Cell', {'cell':that});\n
# 19                   that.events.trigger('edit_mode.Cell', {cell: that});\n
# 20                   that.events.trigger('command_mode.Cell', {cell: that});\n
# 21                   this.events.trigger('select.Cell', {'cell':that});\n
# 22               cell.events.trigger('unrecognized_cell.Cell', {cell: cell});\n
# 23           events.trigger('preset_added.CellToolbar', {name: name});\n
# 24               events.trigger('unregistered_preset.CellToolbar', {name: name});\n
# 25           events.trigger('preset_activated.CellToolbar', {name: preset_name});\n
# 26           this.events.trigger('execute.CodeCell', {cell: this});\n
# 27           this.events.trigger('open_with_text.Pager', payload);\n
# 28           this.events.trigger('set_dirty.Notebook', {value: true});\n
# 29           this.events.trigger('set_next_input.Notebook', data);\n
# ..                                                               ...
# 80           this.events.trigger('kernel_restarting.Kernel', {kernel: this});\n
# 81               that.events.trigger('kernel_created.Kernel', {kernel: that});\n
# 82               that.events.trigger('kernel_dead.Kernel', {kernel: that});\n
# 83           this.events.trigger('kernel_reconnecting.Kernel', {\n
# 84           this.events.trigger('kernel_connected.Kernel', {kernel: this});\n
# 85               that.events.trigger('kernel_ready.Kernel', {kernel: that});\n
# 86                       that.events.trigger('kernel_dead.Kernel', {kernel: that});\n
# 87           this.events.trigger('kernel_disconnected.Kernel', {kernel: this});\n
# 88               this.events.trigger('kernel_connection_failed.Kernel', {kernel: this, ws_url: ws_url, attempt: this._reconnect_attempt});\n
# 89               this.events.trigger('kernel_connection_dead.Kernel', {\n
# 90           this.events.trigger('execution_request.Kernel', {kernel: this, content: content});\n
# 91           this.events.trigger('input_reply.Kernel', {kernel: this, content: content});\n
# 92           this.events.trigger('shell_reply.Kernel', {kernel: this, reply:reply});\n
# 93               this.events.trigger('kernel_busy.Kernel', {kernel: this});\n
# 94               this.events.trigger('kernel_idle.Kernel', {kernel: this});\n
# 95               this.events.trigger('kernel_starting.Kernel', {kernel: this});\n
# 96                   that.events.trigger('kernel_ready.Kernel', {kernel: that});\n
# 97               this.events.trigger('kernel_restarting.Kernel', {kernel: this});\n
# 98               this.events.trigger('kernel_autorestarting.Kernel', {kernel: this, attempt: this._autorestart_attempt});\n
# 99               this.events.trigger('kernel_dead.Kernel', {kernel: this});\n
# 100              this.events.trigger('received_unsolicited_message.Kernel', msg);\n
# 101              this.events.trigger('received_unsolicited_message.Kernel', msg);\n
# 102              that.events.trigger('kernel_created.Session', {session: that, kernel: that.kernel});\n
# 103              that.events.trigger('kernel_dead.Session', {session: that, xhr: xhr, status: status, error: err});\n
# 104              this.events.trigger('kernel_killed.Session', {session: this, kernel: this.kernel});\n
# 105      events.trigger('app_initialized.DashboardApp');\n
# 106          this.events.trigger('kernelspecs_loaded.KernelSpec', data.kernelspecs);\n
# 107          events.trigger('draw_notebook_list.NotebookList');\n
# 108                  events.trigger('notebook_deleted.NotebookList');\n
# 109          this.events.trigger('sessions_loaded.Dashboard', this.sessions);\n
#
# [110 rows x 3 columns]

# %%
pd.set_option('display.max_colwidth', -1)
events_trigger.to_html("events.html")
